# %% [markdown]
# ![실습파일 표지로고(최종).png](attachment:7dd59dfc-0ed9-453c-abbc-6ae08aa0ed0c.png)

# %% [markdown]
# # Part 7 시계열 분석

# %% [markdown]
# ## Chapter 3: 벡터 자기 회귀모형(VAR)

# %%
# 작업공간(working directory)지정  
import os  
os.chdir("X:/Econometrics_with_ML")
os.getcwd()
# Out:
# 'X:\\Econometrics_with_ML'

# %%
# 본서에서 사용되는 모든 Library 불러오기 
exec(open('Functions/Traditional_Econometrics_Lib.py').read())

# %%
"""
# #####################################################################
# 위의 함수는 아래 다양한 라이브러리와 함수를 한 문장으로 불러오는 방법
# #####################################################################

# 분석에 사용될 라이브러리(Libraries for the Analysis) 불러오기
# Libraries for the Analysis of Traditional Econometrics.py
# 불러오는 방법:  "exec(open('Functions/Traditional_Econometrics_Lib.py').read())"
# #####################################################################

# 만약 특정 라이브러리가 설치되지 않았다는 에러 메시지가 나타날 때는 
# 해당 라이브러리를 설치하여야 함
# 아래 라이브러리를 하나 하나 실행하면서 어떤 라이브러리가 설치되지 않았는지 확인하여도 됨
# #####################################################################
import os
import numpy as np                                       # Numerical calculations
import pandas as pd                                      # Data handling
import math as someAlias
import matplotlib.dates as mdates                        # Turn dates into numbers
import matplotlib.pyplot as plt                          # Lower-level graphics
import patsy as pt
import seaborn as sns
import stargazer.stargazer as sg
import statsmodels.api as sm
import statsmodels.formula.api as smf                    # Econometrics
import statsmodels.stats.api as sms
import statsmodels.stats.diagnostic as dg
import statsmodels.stats.outliers_influence as smo
import linearmodels as lm                                # Panel model, Simultaneous Eq. Model
import scipy.stats as stats                              # Statistics
import random

from scipy.optimize import Bounds
from scipy.optimize import curve_fit                    # Nonlinear regression
from scipy.optimize import minimize
from scipy.stats import norm
from statsmodels.graphics import tsaplots               # Time series
from statsmodels.iolib.summary2 import summary_col
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.stattools import durbin_watson
from statsmodels.tsa.api import VAR
from statsmodels.tsa.ar_model import AutoReg, ar_select_order
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller          # ADF test
from statsmodels.tsa.stattools import coint             # Cointegration
from statsmodels.tsa.vector_ar.vecm import VECM
from arch import arch_model

import wooldridge as woo
from imfpy.retrievals import dots
import wbdata
import yfinance as yf

import warnings
warnings.filterwarnings("ignore")
"""\

# %%
# 한국의 거시경제 통계자료 불러오기
data = pd.read_csv('Data/Korea_GDP.csv',index_col='Time', parse_dates=True)
new_index = pd.date_range(start='1961-03-31', periods=len(data), freq='Q')
data.index = pd.to_datetime(new_index)
data.index
# Out:
# DatetimeIndex(['1961-03-31', '1961-06-30', '1961-09-30', '1961-12-31',
#                '1962-03-31', '1962-06-30', '1962-09-30', '1962-12-31',
#                '1963-03-31', '1963-06-30',
#                ...
#                '2021-09-30', '2021-12-31', '2022-03-31', '2022-06-30',
#                '2022-09-30', '2022-12-31', '2023-03-31', '2023-06-30',
#                '2023-09-30', '2023-12-31'],
#               dtype='datetime64[ns]', length=252, freq='QE-DEC')

# %%
df = data[[ 'gdp', 'inv', 'con']]
df
# Out:
#                  gdp       inv       con
# 1961-03-31    7000.7    -659.9    8957.5
# 1961-06-30    8141.3    1736.8    6593.8
# 1961-09-30    6970.2     833.2    6308.6
# 1961-12-31    8974.2     950.7    8740.5
# 1962-03-31    7444.8    -727.9    9670.8
# ...              ...       ...       ...
# 2022-12-31  513770.2  159480.4  235677.7
# 2023-03-31  472155.5  132942.8  233780.3
# 2023-06-30  497345.6  146189.8  229263.8
# 2023-09-30  500997.0  148498.3  233387.8
# 2023-12-31  525122.8  155198.8  237874.7
#
# [252 rows x 3 columns]

# %%
# 퍼센트 변화(percent change) 
df_gr = 100*df.pct_change(periods=4).dropna()
df_gr = df_gr.loc['1970-01-31':]
print(df_gr)
# Out:
#                   gdp        inv        con
# 1970-03-31  10.549933  15.182119   9.949197
# 1970-06-30  13.740925   8.154760  12.070927
# 1970-09-30   4.770876 -16.469740  13.047604
# 1970-12-31  11.190926   8.575264   7.720308
# 1971-03-31  12.769138  24.960471  10.245914
# ...               ...        ...        ...
# 2022-12-31   1.396643   1.544364   3.266275
# 2023-03-31   0.898427   6.390072   4.555105
# 2023-06-30   0.888950   2.290931   1.571933
# 2023-09-30   1.384668  -1.694775   0.249133
# 2023-12-31   2.209665  -2.684719   0.932205
#
# [216 rows x 3 columns]

# %%
df_gr.plot(figsize=(10, 4));

# %% [markdown]
# ### 나. VAR 모형의 차수 결정

# %%
for i in range(1, 9):
    model = VAR(df_gr)
    results = model.fit(i)
    print('Order =', i)
    print('AIC: ', results.aic)
    print('BIC: ', results.bic)
    print()
# Out:
# Order = 1
# AIC:  8.449275022670554
# BIC:  8.63740365679861
#
# Order = 2
# AIC:  8.364350313445808
# BIC:  8.69465637099468
#
# Order = 3
# AIC:  8.275765791007187
# BIC:  8.749187222797246
#
# Order = 4
# AIC:  8.264258918474475
# BIC:  8.881744129381119
#
# Order = 5
# AIC:  8.250825404895057
# BIC:  9.013333416301935
#
# Order = 6
# AIC:  8.28239204021608
# BIC:  9.190892655696537
#
# Order = 7
# AIC:  8.335843746843201
# BIC:  9.391317721147878
#
# Order = 8
# AIC:  8.283773390616574
# BIC:  9.487212602047338

# %%
# 적정시치 확인
model.select_order(8)
results = model.fit(maxlags=8, ic='aic')
lag_order = results.k_ar
print(lag_order)
# Out:
# 2

# %% [markdown]
# ### 다. 모형의 추정

# %%
model = VAR(df_gr)
results = model.fit(5)
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 19, Aug, 2025
# Time:                     15:17:17
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    9.01333
# Nobs:                     211.000    HQIC:                   8.55905
# Log likelihood:          -1720.65    FPE:                    3834.14
# AIC:                      8.25083    Det(Omega_mle):         3079.20
# --------------------------------------------------------------------
# Results for equation gdp
# =========================================================================
#             coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------
# const          0.593682         0.358214            1.657           0.097
# L1.gdp         0.704255         0.092925            7.579           0.000
# L1.inv        -0.009616         0.012194           -0.789           0.430
# L1.con         0.351023         0.087329            4.020           0.000
# L2.gdp         0.236327         0.104652            2.258           0.024
# L2.inv        -0.003954         0.012384           -0.319           0.750
# L2.con        -0.245067         0.103229           -2.374           0.018
# L3.gdp        -0.024976         0.100310           -0.249           0.803
# L3.inv        -0.030825         0.012425           -2.481           0.013
# L3.con        -0.001558         0.101691           -0.015           0.988
# L4.gdp        -0.175703         0.097124           -1.809           0.070
# L4.inv         0.000289         0.012531            0.023           0.982
# L4.con        -0.176482         0.100907           -1.749           0.080
# L5.gdp         0.233374         0.089918            2.595           0.009
# L5.inv         0.000283         0.012311            0.023           0.982
# L5.con         0.056773         0.086702            0.655           0.513
# =========================================================================
#
# Results for equation inv
# =========================================================================
#             coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------
# const         -3.971805         2.347509           -1.692           0.091
# L1.gdp         2.196706         0.608972            3.607           0.000
# L1.inv         0.115764         0.079909            1.449           0.147
# L1.con         0.399223         0.572300            0.698           0.485
# L2.gdp         0.530005         0.685823            0.773           0.440
# L2.inv         0.108830         0.081159            1.341           0.180
# L2.con        -0.853495         0.676497           -1.262           0.207
# L3.gdp        -0.813883         0.657372           -1.238           0.216
# L3.inv        -0.046270         0.081428           -0.568           0.570
# L3.con         0.106749         0.666420            0.160           0.873
# L4.gdp        -0.102592         0.636488           -0.161           0.872
# L4.inv         0.037737         0.082122            0.460           0.646
# L4.con        -0.916616         0.661283           -1.386           0.166
# L5.gdp         0.768377         0.589269            1.304           0.192
# L5.inv        -0.001752         0.080680           -0.022           0.983
# L5.con         0.110925         0.568194            0.195           0.845
# =========================================================================
#
# Results for equation con
# =========================================================================
#             coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------
# const          0.427947         0.354450            1.207           0.227
# L1.gdp         0.156365         0.091948            1.701           0.089
# L1.inv         0.013531         0.012065            1.121           0.262
# L1.con         0.830321         0.086411            9.609           0.000
# L2.gdp        -0.043170         0.103552           -0.417           0.677
# L2.inv        -0.005837         0.012254           -0.476           0.634
# L2.con         0.030934         0.102144            0.303           0.762
# L3.gdp        -0.095881         0.099256           -0.966           0.334
# L3.inv        -0.016127         0.012295           -1.312           0.190
# L3.con         0.030293         0.100623            0.301           0.763
# L4.gdp         0.066040         0.096103            0.687           0.492
# L4.inv        -0.003759         0.012400           -0.303           0.762
# L4.con        -0.346783         0.099847           -3.473           0.001
# L5.gdp         0.182077         0.088974            2.046           0.041
# L5.inv        -0.002911         0.012182           -0.239           0.811
# L5.con         0.062317         0.085791            0.726           0.468
# =========================================================================
#
# Correlation matrix of residuals
#             gdp       inv       con
# gdp    1.000000  0.442106  0.562598
# inv    0.442106  1.000000  0.207522
# con    0.562598  0.207522  1.000000

# %%
results.plot();

# %% [markdown]
# ### 라. 진단

# %% [markdown]
# #### 1) 잔차의 자기상관 여부 검정

# %%
results.plot_acorr();

# %% [markdown]
# #### 2) 잔차의 정규성 여부 검정

# %%
nor = results.test_normality()
nor.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# #### 3) 인과성

# %%
cau_gdp = results.test_causality('gdp', ['inv', 'con'], kind='f')
cau_gdp.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ### 마. 충격 반응함수
# #### 1) 충격 반응함수

# %%
irf = results.irf(10)  
irf.plot(orth=False);

# %% [markdown]
# #### 2) 직교화된 충격 반응함수

# %%
irf = results.irf(10)  
irf.plot(orth=True);

# %%
irf.plot(impulse='gdp', );

# %%
irf.plot(impulse='gdp', orth=True);

# %% [markdown]
# #### [보완] 누적 충격반응 함수

# %%
irf.plot_cum_effects(orth=False);

# %% [markdown]
# #### [보완] 직교화된 누적 충격반응 함수

# %%
irf.plot_cum_effects(orth=True);

# %% [markdown]
# ### 바. 예측 오차 분산의 분해

# %%
fevd = results.fevd(10)
fevd.summary()
# Out:
# FEVD for gdp
#           gdp       inv       con
# 0    1.000000  0.000000  0.000000
# 1    0.952663  0.002843  0.044494
# 2    0.946323  0.003027  0.050650
# 3    0.914923  0.021411  0.063666
# 4    0.899320  0.035189  0.065490
# 5    0.885832  0.051227  0.062941
# 6    0.870912  0.065868  0.063220
# 7    0.858907  0.072971  0.068122
# 8    0.851780  0.078052  0.070168
# 9    0.849364  0.080719  0.069916
#
# FEVD for inv
#           gdp       inv       con
# 0    0.195458  0.804542  0.000000
# 1    0.312868  0.685051  0.002082
# 2    0.405139  0.592107  0.002754
# 3    0.436786  0.556738  0.006477
# 4    0.445311  0.546034  0.008655
# 5    0.443155  0.542717  0.014129
# 6    0.437942  0.539160  0.022899
# 7    0.433402  0.534043  0.032555
# 8    0.433014  0.530956  0.036031
# 9    0.434709  0.528657  0.036633
#
# FEVD for con
#           gdp       inv       con
# 0    0.316516  0.002110  0.681373
# 1    0.396373  0.002035  0.601592
# 2    0.438528  0.001397  0.560076
# 3    0.446772  0.003933  0.549295
# 4    0.454471  0.008813  0.536716
# 5    0.458843  0.018256  0.522901
# 6    0.457876  0.027430  0.514694
# 7    0.453892  0.033834  0.512274
# 8    0.453413  0.038953  0.507633
# 9    0.455646  0.042081  0.502273

# %%
results.fevd(20).plot();

# %% [markdown]
# ### 사. 예측

# %%
results.forecast(df_gr.values[lag_order:], 20)
# Out:
# array([[ 2.23241346, -1.97490974,  0.3034461 ],
#        [ 2.6501556 , -0.37514797,  0.7873005 ],
#        [ 3.23677992,  1.67431623,  1.53975455],
#        [ 3.6203555 ,  2.85771073,  2.07966745],
#        [ 4.29246898,  4.89442747,  2.95129127],
#        [ 4.7383257 ,  5.85443358,  3.55107812],
#        [ 5.03404994,  6.40837745,  3.95000641],
#        [ 5.26854407,  6.60307393,  4.23918338],
#        [ 5.31076912,  6.35095226,  4.30937901],
#        [ 5.3492715 ,  6.16774016,  4.33194108],
#        [ 5.38370509,  6.03849242,  4.33404109],
#        [ 5.42047751,  6.05474675,  4.33323365],
#        [ 5.51003712,  6.25275203,  4.37735612],
#        [ 5.60160701,  6.4992803 ,  4.43601834],
#        [ 5.69622454,  6.77505487,  4.50589287],
#        [ 5.78442029,  7.01517192,  4.57784049],
#        [ 5.84872261,  7.19226069,  4.63657547],
#        [ 5.90130249,  7.32612445,  4.68666634],
#        [ 5.94090752,  7.41822038,  4.72674012],
#        [ 5.97244778,  7.49134024,  4.75946017]])

# %%
results.plot_forecast(20);

# %% [markdown]
# ## 3. VAR 모형의 확장
# ### 가. VARX, VMA, VARMA 모형

# %%
# 한국의 거시경제 통계자료 불러오기
data = pd.read_csv('Data/Korea_GDP.csv',index_col='Time', parse_dates=True)
new_index = pd.date_range(start='1961-03-31', periods=len(data), freq='Q')
data.index = pd.to_datetime(new_index)
data.index

df = data[[ 'gdp', 'inv', 'con', 'gov']]
df
# Out:
#                  gdp       inv       con      gov
# 1961-03-31    7000.7    -659.9    8957.5   3036.1
# 1961-06-30    8141.3    1736.8    6593.8   3079.9
# 1961-09-30    6970.2     833.2    6308.6   2980.0
# 1961-12-31    8974.2     950.7    8740.5   2922.3
# 1962-03-31    7444.8    -727.9    9670.8   3058.9
# ...              ...       ...       ...      ...
# 2022-12-31  513770.2  159480.4  235677.7  89949.2
# 2023-03-31  472155.5  132942.8  233780.3  94700.5
# 2023-06-30  497345.6  146189.8  229263.8  89060.8
# 2023-09-30  500997.0  148498.3  233387.8  82449.8
# 2023-12-31  525122.8  155198.8  237874.7  89118.4
#
# [252 rows x 4 columns]

# %%
# 퍼센트 변화(percent change) 
df_gr = 100*df.pct_change(periods=4).dropna()
df_gr = df_gr.loc['1970-01-31':]
print(df_gr)
# Out:
#                   gdp        inv        con        gov
# 1970-03-31  10.549933  15.182119   9.949197  11.268465
# 1970-06-30  13.740925   8.154760  12.070927  10.218029
# 1970-09-30   4.770876 -16.469740  13.047604   5.365489
# 1970-12-31  11.190926   8.575264   7.720308   2.895987
# 1971-03-31  12.769138  24.960471  10.245914   8.024285
# ...               ...        ...        ...        ...
# 2022-12-31   1.396643   1.544364   3.266275   3.633842
# 2023-03-31   0.898427   6.390072   4.555105   4.038359
# 2023-06-30   0.888950   2.290931   1.571933   0.955933
# 2023-09-30   1.384668  -1.694775   0.249133   1.093703
# 2023-12-31   2.209665  -2.684719   0.932205  -0.923632
#
# [216 rows x 4 columns]

# %%
endog = df_gr.loc[:, ['gdp', 'inv', 'con']]
exog = df_gr.loc[:, 'gov']

# %%
# VARX 
Model_VAR = VARMAX(endog=endog, order=(5,0), exog=exog)
Results_VAR = Model_VAR.fit(maxiter=1000, disp=False)

print(Results_VAR.summary())
# Out:
#                              Statespace Model Results
# =================================================================================
# Dep. Variable:     ['gdp', 'inv', 'con']   No. Observations:                  216
# Model:                           VARX(5)   Log Likelihood               -1776.193
#                              + intercept   AIC                           3666.387
# Date:                   Tue, 19 Aug 2025   BIC                           3858.778
# Time:                           15:28:37   HQIC                          3744.113
# Sample:                       03-31-1970
#                             - 12-31-2023
# Covariance Type:                     opg
# =======================================================================================
# Ljung-Box (L1) (Q):       0.00, 0.00, 0.02   Jarque-Bera (JB):   31.98, 4525.28, 419.97
# Prob(Q):                  0.99, 1.00, 0.88   Prob(JB):                 0.00, 0.00, 0.00
# Heteroskedasticity (H):   0.17, 0.10, 0.42   Skew:                   -0.11, 2.61, -0.79
# Prob(H) (two-sided):      0.00, 0.00, 0.00   Kurtosis:                4.87, 24.81, 9.65
#                            Results for equation gdp
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.5005      0.816      0.614      0.539      -1.098       2.099
# L1.gdp         0.6704      0.122      5.486      0.000       0.431       0.910
# L1.inv        -0.0080      0.026     -0.306      0.759      -0.059       0.043
# L1.con         0.3396      0.108      3.142      0.002       0.128       0.551
# L2.gdp         0.2289      0.124      1.839      0.066      -0.015       0.473
# L2.inv        -0.0062      0.016     -0.393      0.694      -0.037       0.025
# L2.con        -0.1864      0.133     -1.400      0.162      -0.447       0.075
# L3.gdp         0.0353      0.137      0.258      0.797      -0.233       0.304
# L3.inv        -0.0361      0.026     -1.414      0.158      -0.086       0.014
# L3.con        -0.0308      0.145     -0.212      0.832      -0.315       0.253
# L4.gdp        -0.2047      0.134     -1.524      0.127      -0.468       0.059
# L4.inv         0.0006      0.022      0.027      0.979      -0.043       0.044
# L4.con        -0.1851      0.122     -1.515      0.130      -0.425       0.054
# L5.gdp         0.2423      0.124      1.962      0.050       0.000       0.484
# L5.inv         0.0005      0.017      0.030      0.976      -0.033       0.034
# L5.con         0.0600      0.103      0.581      0.561      -0.142       0.262
# beta.gov       0.0223      0.086      0.259      0.795      -0.146       0.191
#                            Results for equation inv
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -3.9977      6.434     -0.621      0.534     -16.608       8.613
# L1.gdp         2.1176      1.012      2.092      0.036       0.134       4.101
# L1.inv         0.1276      0.109      1.169      0.242      -0.086       0.342
# L1.con         0.2823      0.998      0.283      0.777      -1.673       2.238
# L2.gdp         0.4266      1.029      0.415      0.678      -1.590       2.443
# L2.inv         0.0993      0.162      0.612      0.541      -0.219       0.417
# L2.con        -0.5977      1.089     -0.549      0.583      -2.733       1.537
# L3.gdp        -0.6087      1.074     -0.566      0.571      -2.715       1.497
# L3.inv        -0.0660      0.115     -0.574      0.566      -0.291       0.159
# L3.con         0.0238      1.373      0.017      0.986      -2.667       2.714
# L4.gdp        -0.2033      1.332     -0.153      0.879      -2.814       2.407
# L4.inv         0.0406      0.077      0.527      0.598      -0.110       0.191
# L4.con        -0.9492      1.049     -0.905      0.365      -3.005       1.107
# L5.gdp         0.8180      1.189      0.688      0.491      -1.511       3.147
# L5.inv        -0.0004      0.148     -0.003      0.998      -0.290       0.289
# L5.con         0.1053      1.012      0.104      0.917      -1.878       2.088
# beta.gov       0.0271      0.773      0.035      0.972      -1.487       1.541
#                            Results for equation con
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.1340      0.732      0.183      0.855      -1.302       1.570
# L1.gdp         0.2154      0.164      1.316      0.188      -0.105       0.536
# L1.inv         0.0128      0.023      0.547      0.584      -0.033       0.059
# L1.con         0.7889      0.120      6.583      0.000       0.554       1.024
# L2.gdp        -0.0948      0.180     -0.527      0.598      -0.447       0.257
# L2.inv        -0.0043      0.022     -0.199      0.842      -0.047       0.038
# L2.con         0.0497      0.186      0.267      0.789      -0.315       0.414
# L3.gdp        -0.0682      0.173     -0.393      0.694      -0.408       0.272
# L3.inv        -0.0181      0.028     -0.643      0.520      -0.073       0.037
# L3.con         0.0412      0.145      0.284      0.776      -0.242       0.325
# L4.gdp         0.0644      0.179      0.360      0.719      -0.286       0.415
# L4.inv        -0.0042      0.036     -0.117      0.907      -0.074       0.065
# L4.con        -0.3490      0.119     -2.923      0.003      -0.583      -0.115
# L5.gdp         0.1637      0.181      0.905      0.365      -0.191       0.518
# L5.inv        -0.0027      0.027     -0.098      0.922      -0.056       0.051
# L5.con         0.0641      0.118      0.544      0.586      -0.167       0.295
# beta.gov       0.0587      0.091      0.648      0.517      -0.119       0.236
#                               Error covariance matrix
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sqrt.var.gdp         2.2602      0.142     15.865      0.000       1.981       2.539
# sqrt.cov.gdp.inv     6.6932      1.945      3.441      0.001       2.881      10.505
# sqrt.var.inv        12.7402      0.532     23.967      0.000      11.698      13.782
# sqrt.cov.gdp.con     1.1434      0.200      5.731      0.000       0.752       1.534
# sqrt.cov.inv.con    -0.1348      0.286     -0.471      0.638      -0.696       0.427
# sqrt.var.con         1.8200      0.105     17.410      0.000       1.615       2.025
# ====================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
ax = Results_VAR.impulse_responses(10, orthogonalized=True, impulse=[1, 0, 0]).plot(figsize=(12,4))
ax.set(xlabel='t', title='Responses to a shock to `gdp`');

# %%
ax = Results_VAR.impulse_responses(10, orthogonalized=True, impulse=[0, 1, 0]).plot(figsize=(12,4))
ax.set(xlabel='t', title='Responses to a shock to `inv`');

# %%
ax = Results_VAR.impulse_responses(10, orthogonalized=True, impulse=[0, 0, 1]).plot(figsize=(12,4))
ax.set(xlabel='t', title='Responses to a shock to `con`');

# %%
# VMA 
Model_VMA = VARMAX(endog, order=(0, 2), error_cov_type='diagonal')
Results_VMA = Model_VMA.fit(maxiter=1000, disp=False)
print(Results_VMA.summary())
# Out:
#                              Statespace Model Results
# =================================================================================
# Dep. Variable:     ['gdp', 'inv', 'con']   No. Observations:                  216
# Model:                            VMA(2)   Log Likelihood               -1941.062
#                              + intercept   AIC                           3930.124
# Date:                   Thu, 24 Jul 2025   BIC                           4011.131
# Time:                           10:35:52   HQIC                          3962.851
# Sample:                       03-31-1970
#                             - 12-31-2023
# Covariance Type:                     opg
# =======================================================================================
# Ljung-Box (L1) (Q):      2.22, 2.53, 17.03   Jarque-Bera (JB):   30.78, 3578.63, 120.56
# Prob(Q):                  0.14, 0.11, 0.00   Prob(JB):                 0.00, 0.00, 0.00
# Heteroskedasticity (H):   0.25, 0.10, 0.85   Skew:                    0.59, 2.81, -0.66
# Prob(H) (two-sided):      0.00, 0.00, 0.50   Kurtosis:                4.42, 22.13, 6.42
#                            Results for equation gdp
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      6.6537      0.366     18.172      0.000       5.936       7.371
# L1.e(gdp)      0.3699      0.101      3.674      0.000       0.173       0.567
# L1.e(inv)      0.0239      0.021      1.144      0.253      -0.017       0.065
# L1.e(con)      0.6342      0.097      6.547      0.000       0.444       0.824
# L2.e(gdp)      0.2250      0.119      1.895      0.058      -0.008       0.458
# L2.e(inv)      0.0476      0.016      3.070      0.002       0.017       0.078
# L2.e(con)      0.4262      0.121      3.517      0.000       0.189       0.664
#                            Results for equation inv
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      8.8211      2.776      3.178      0.001       3.380      14.262
# L1.e(gdp)     -0.2677      0.846     -0.317      0.752      -1.925       1.390
# L1.e(inv)      0.3164      0.093      3.395      0.001       0.134       0.499
# L1.e(con)      0.3605      0.696      0.518      0.605      -1.004       1.726
# L2.e(gdp)      0.2842      0.777      0.366      0.714      -1.238       1.806
# L2.e(inv)      0.2516      0.111      2.261      0.024       0.033       0.470
# L2.e(con)     -0.2504      0.767     -0.326      0.744      -1.753       1.253
#                            Results for equation con
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      5.4002      0.616      8.766      0.000       4.193       6.608
# L1.e(gdp)     -0.0793      0.112     -0.711      0.477      -0.298       0.139
# L1.e(inv)      0.0416      0.017      2.433      0.015       0.008       0.075
# L1.e(con)      0.8084      0.088      9.159      0.000       0.635       0.981
# L2.e(gdp)     -0.1502      0.104     -1.439      0.150      -0.355       0.054
# L2.e(inv)      0.0345      0.012      2.779      0.005       0.010       0.059
# L2.e(con)      0.2952      0.087      3.375      0.001       0.124       0.467
#                            Error covariance matrix
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2.gdp     6.7887      0.725      9.366      0.000       5.368       8.209
# sigma2.inv   255.6819     22.458     11.385      0.000     211.664     299.699
# sigma2.con     7.3783      0.603     12.228      0.000       6.196       8.561
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# VARMA(p,q)
Model_VARMA = VARMAX(endog, order=(2,2))
Results_VARMA = Model_VARMA.fit(maxiter=1000, disp=False)
print(Results_VARMA.summary())
# Out:
#                              Statespace Model Results
# =================================================================================
# Dep. Variable:     ['gdp', 'inv', 'con']   No. Observations:                  216
# Model:                        VARMA(2,2)   Log Likelihood               -1771.020
#                              + intercept   AIC                           3632.040
# Date:                   Thu, 24 Jul 2025   BIC                           3783.927
# Time:                           10:40:04   HQIC                          3693.403
# Sample:                       03-31-1970
#                             - 12-31-2023
# Covariance Type:                     opg
# =======================================================================================
# Ljung-Box (L1) (Q):       0.33, 1.43, 0.00   Jarque-Bera (JB):   13.77, 3690.52, 318.51
# Prob(Q):                  0.57, 0.23, 0.97   Prob(JB):                 0.00, 0.00, 0.00
# Heteroskedasticity (H):   0.19, 0.10, 0.44   Skew:                    0.07, 2.50, -0.89
# Prob(H) (two-sided):      0.00, 0.00, 0.00   Kurtosis:                4.23, 22.63, 8.67
#                            Results for equation gdp
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.3602      1.096     -0.329      0.742      -2.509       1.788
# L1.gdp        -0.2412      1.402     -0.172      0.863      -2.988       2.506
# L1.inv         0.2271      0.346      0.657      0.511      -0.450       0.905
# L1.con         0.7081      0.927      0.764      0.445      -1.109       2.525
# L2.gdp         1.5479      1.166      1.327      0.185      -0.738       3.834
# L2.inv        -0.3973      0.252     -1.575      0.115      -0.892       0.097
# L2.con        -0.7418      0.612     -1.213      0.225      -1.941       0.457
# L1.e(gdp)      0.8007      1.419      0.564      0.573      -1.981       3.583
# L1.e(inv)     -0.2263      0.348     -0.651      0.515      -0.908       0.455
# L1.e(con)     -0.3750      0.921     -0.407      0.684      -2.181       1.431
# L2.e(gdp)     -1.2617      1.305     -0.967      0.334      -3.819       1.295
# L2.e(inv)      0.3667      0.217      1.692      0.091      -0.058       0.791
# L2.e(con)      0.4721      0.530      0.891      0.373      -0.567       1.511
#                            Results for equation inv
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -2.9651      6.509     -0.456      0.649     -15.722       9.792
# L1.gdp        -1.6577      3.561     -0.466      0.642      -8.637       5.322
# L1.inv         1.0625      0.868      1.224      0.221      -0.639       2.764
# L1.con         0.7728      2.018      0.383      0.702      -3.182       4.728
# L2.gdp         3.7464      2.928      1.279      0.201      -1.992       9.485
# L2.inv        -1.1149      0.615     -1.813      0.070      -2.320       0.091
# L2.con        -1.0763      1.437     -0.749      0.454      -3.892       1.739
# L1.e(gdp)      4.0284      3.679      1.095      0.273      -3.182      11.238
# L1.e(inv)     -0.9622      0.871     -1.104      0.269      -2.670       0.745
# L1.e(con)     -0.6094      1.694     -0.360      0.719      -3.930       2.711
# L2.e(gdp)     -2.2771      3.406     -0.669      0.504      -8.953       4.399
# L2.e(inv)      1.0768      0.534      2.018      0.044       0.031       2.123
# L2.e(con)      1.2943      1.525      0.849      0.396      -1.695       4.283
#                            Results for equation con
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0722      1.195      0.060      0.952      -2.270       2.414
# L1.gdp        -1.3371      1.596     -0.838      0.402      -4.465       1.791
# L1.inv         0.3647      0.387      0.943      0.346      -0.393       1.123
# L1.con         1.2486      1.057      1.182      0.237      -0.822       3.320
# L2.gdp         1.8799      1.311      1.434      0.152      -0.689       4.449
# L2.inv        -0.3959      0.276     -1.433      0.152      -0.938       0.146
# L2.con        -0.8774      0.662     -1.324      0.185      -2.176       0.421
# L1.e(gdp)      1.5865      1.603      0.989      0.322      -1.556       4.729
# L1.e(inv)     -0.3541      0.388     -0.912      0.362      -1.115       0.407
# L1.e(con)     -0.4458      1.050     -0.425      0.671      -2.503       1.611
# L2.e(gdp)     -2.0220      1.476     -1.370      0.171      -4.914       0.870
# L2.e(inv)      0.3624      0.238      1.521      0.128      -0.104       0.829
# L2.e(con)      1.0234      0.647      1.581      0.114      -0.245       2.292
#                               Error covariance matrix
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sqrt.var.gdp         2.1265      0.163     13.032      0.000       1.807       2.446
# sqrt.cov.gdp.inv     6.0566      1.790      3.384      0.001       2.549       9.565
# sqrt.var.inv        13.0121      0.508     25.618      0.000      12.017      14.008
# sqrt.cov.gdp.con     0.9436      0.224      4.206      0.000       0.504       1.383
# sqrt.cov.inv.con    -0.1632      0.201     -0.810      0.418      -0.558       0.231
# sqrt.var.con         1.8426      0.104     17.803      0.000       1.640       2.045
# ====================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### 나. 구조적 VAR 모형

# %%
# SVAR모형의 A, B 정의 
A = np.asarray([[1, 0, 0],['E', 1, 0],['E', 'E', 1]])
B = np.asarray([['E', 0, 0], [0, 'E', 0], [0, 0, 'E']])

# 초깃값 부여
A_guess = np.asarray([0.5, 0.25, -0.38]) 
B_guess = np.asarray([0.5, 0.1, 0.05]) 

# SVAR모형 정의
mymodel = SVAR(endog, svar_type='AB', A=A, B=B, freq='Q')

# SVAR모형 추정
res = mymodel.fit(A_guess=A_guess, B_guess=B_guess, maxlags=2, maxiter=10000, maxfun=10000, solver='bfgs')

# 충격반응함수 그래프
res.irf(periods=20).plot(impulse='gdp', plot_stderr=True,
                             stderr_type='mc', repl=100);
