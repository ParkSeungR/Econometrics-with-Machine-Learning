# %% [markdown]
# ![실습파일 표지로고(최종).png](attachment:4333cb0a-93d0-4ce3-8821-159a0c64c120.png)

# %% [markdown]
# # 전통적 계량경제학 전반

# %%
exec(open('E:/JupyterWDirectory/MyStock/Functions/Traditional_Econometrics_Lib.py').read())
exec(open('E:/JupyterWDirectory/MyStock/Functions/Run_Comprehensive_OLS_analysis.py').read())

# 데이터 로드 및 변수명 변경
phillips_data = woo.dataWoo('phillips')
phillips_data['inflation'] = phillips_data['inf'] 
display(phillips_data)
Run_Comprehensive_OLS_analysis(phillips_data, 'inflation', ['unem'], data_type='time_series')

# 횡단면 자료
# 데이터 읽어들이기, 필요한 변수, 관측치 선택
gpa3 = woo.dataWoo('gpa3')
gpa3 = gpa3[gpa3['spring'] == 1]
df = gpa3[['cumgpa', 'sat', 'hsperc', 'tothrs', 'female', 'black', 'white']]
display(df)

# 전통적 계량경제학 전반
Run_Comprehensive_OLS_analysis(df, 'cumgpa', ['sat', 'hsperc', 'tothrs', 'female', 'black', 'white'], data_type='cross_sectional')
# Out:
# 이 함수는 전통적 계량경제학 종합 분석 함수입니다.
#     year  unem   inf  inf_1  unem_1  cinf     cunem  inflation
# 0   1948   3.8   8.1    NaN     NaN   NaN       NaN        8.1
# 1   1949   5.9  -1.2    8.1     3.8  -9.3  2.100000       -1.2
# 2   1950   5.3   1.3   -1.2     5.9   2.5 -0.600000        1.3
# 3   1951   3.3   7.9    1.3     5.3   6.6 -2.000000        7.9
# 4   1952   3.0   1.9    7.9     3.3  -6.0 -0.300000        1.9
# 5   1953   2.9   0.8    1.9     3.0  -1.1 -0.100000        0.8
# 6   1954   5.5   0.7    0.8     2.9  -0.1  2.600000        0.7
# 7   1955   4.4  -0.4    0.7     5.5  -1.1 -1.100000       -0.4
# 8   1956   4.1   1.5   -0.4     4.4   1.9 -0.300000        1.5
# 9   1957   4.3   3.3    1.5     4.1   1.8  0.200000        3.3
# 10  1958   6.8   2.8    3.3     4.3  -0.5  2.500000        2.8
# 11  1959   5.5   0.7    2.8     6.8  -2.1 -1.300000        0.7
# 12  1960   5.5   1.7    0.7     5.5   1.0  0.000000        1.7
# ...

# %%
# 시계열 자료
# 데이터 읽어들이기 및 변수명 변경
phillips_data = woo.dataWoo('phillips')
phillips_data['inflation'] = phillips_data['inf']  
display(phillips_data)

# 전통적 계량경제학 전반(
Run_Comprehensive_OLS_analysis(phillips_data, 'inflation', ['unem'], data_type='time_series')
# Out:
#     year  unem   inf  inf_1  unem_1  cinf     cunem  inflation
# 0   1948   3.8   8.1    NaN     NaN   NaN       NaN        8.1
# 1   1949   5.9  -1.2    8.1     3.8  -9.3  2.100000       -1.2
# 2   1950   5.3   1.3   -1.2     5.9   2.5 -0.600000        1.3
# 3   1951   3.3   7.9    1.3     5.3   6.6 -2.000000        7.9
# 4   1952   3.0   1.9    7.9     3.3  -6.0 -0.300000        1.9
# 5   1953   2.9   0.8    1.9     3.0  -1.1 -0.100000        0.8
# 6   1954   5.5   0.7    0.8     2.9  -0.1  2.600000        0.7
# 7   1955   4.4  -0.4    0.7     5.5  -1.1 -1.100000       -0.4
# 8   1956   4.1   1.5   -0.4     4.4   1.9 -0.300000        1.5
# 9   1957   4.3   3.3    1.5     4.1   1.8  0.200000        3.3
# 10  1958   6.8   2.8    3.3     4.3  -0.5  2.500000        2.8
# 11  1959   5.5   0.7    2.8     6.8  -2.1 -1.300000        0.7
# 12  1960   5.5   1.7    0.7     5.5   1.0  0.000000        1.7
# 13  1961   6.7   1.0    1.7     5.5  -0.7  1.200000        1.0
# ...

# %% [markdown]
# # 연립방정식 모형 전반

# %%
exec(open('E:/JupyterWDirectory/MyStock/Functions/Run_Estimate_auto_IV_system.py').read())

# %%
# 데이터 로딩 및 방정식 정의 (기존과 동일)
from linearmodels.datasets import mroz

data = mroz.load()
data = data[["hours", "educ", "age", "kidslt6", "nwifeinc", "lwage", "exper", "expersq"]].dropna()

equations = {
    'hours': 'hours ~ educ + age + kidslt6 + nwifeinc + lwage',
    'lwage': 'lwage ~ educ + exper + expersq + hours'
}

# 다양한 방법의 연립방정식 모형 추정
Run_Estimate_auto_IV_system(data, equations)
# Out:
# --- 1. 데이터 준비 ---
# 사용된 변수: ['age', 'educ', 'exper', 'expersq', 'hours', 'kidslt6', 'lwage', 'nwifeinc']
# 전체 시스템의 외생변수 (개념적 IV 풀): ['age', 'educ', 'exper', 'expersq', 'kidslt6', 'nwifeinc']
#
# 기술통계량:
#          nwifeinc       lwage         age        educ     kidslt6       exper  \
# count  428.000000  428.000000  428.000000  428.000000  428.000000  428.000000
# mean    18.937619    1.190173   41.971963   12.658879    0.140187   13.037383
# std     10.591111    0.723198    7.721084    2.285376    0.391923    8.055923
# min      0.029057   -2.054164   30.000000    5.000000    0.000000    0.000000
# 25%     12.365248    0.816509   35.000000   12.000000    0.000000    7.000000
# 50%     17.080000    1.247574   42.000000   12.000000    0.000000   12.000000
# 75%     23.515000    1.603571   47.250000   14.000000    0.000000   18.000000
# max     91.000000    3.218876   60.000000   17.000000    2.000000   38.000000
#
#            expersq        hours
# count   428.000000   428.000000
# ...

# %% [markdown]
# # 확률적 변경생산함수와 총요소생산성 분해

# %%
exec(open('E:/JupyterWDirectory/MyStock/Functions/Run_StochasticFrontierProduction.py').read())

# %%
# 데이터 불러오기
df = pd.read_excel('data\TFPComp.xlsx', sheet_name='data' )
display(df) 

# 확률적 변경생산함수와 총요소생산성 분해
Run_StochasticFrontierProduction(
    data=df,
    output_var='y', 
    input_vars=['l', 'k', 'f', 'm'],
    time_var='year',
    id_var='id',
    include_time=True,
    save_path='Output/SF_results.csv' 
)
# Out:
#      id  year     y      l     k      f           m          pl          pk  \
# 0     1     1  7.87  161.0  2.50  207.5   52.863763   66.234037   3821.7680
# 1     1     2  7.18  138.0  2.50  295.5   56.417048   59.010652   2966.8089
# 2     1     3  8.92  140.0  2.50  362.5  248.361620   71.883786   4925.8810
# 3     1     4  7.31  127.0  2.50  338.0  249.031280   61.053858   4240.7887
# 4     1     5  7.54  145.0  2.50  337.5  225.938370   80.920828   4457.4614
# ..   ..   ...   ...    ...   ...    ...         ...         ...         ...
# 339  43     4  3.31   67.0  2.00   68.0   14.278499   71.508060   1770.2511
# 340  43     5  5.61   96.0  2.00   94.5  168.876290   84.124167   3968.0599
# 341  43     6  7.78   97.0  1.75  129.4   92.618979   57.357938  12207.3420
# 342  43     7  3.70   35.0  1.75  107.1   26.363011  162.443430   3267.6339
# 343  43     8  7.73   81.0  2.00  118.4   28.860614   88.906667   8571.7073
#
# ...

# %% [markdown]
# # 확률적 변경비용함수와 총요소생산성 분해

# %%
exec(open('E:/JupyterWDirectory/MyStock/Functions/Run_StochasticFrontierCost.py').read())

# %%
# 데이터 불러오기
df = pd.read_excel('data\TFPComp.xlsx', sheet_name='data' )
df['TC'] = df['pl']*df['l'] + df['pk']*df['k'] + df['pf']*df['f'] + df['pm']*df['m']
display(df) 

# 확률적 변경비용함수와 총요소생산성 분해
Run_StochasticFrontierCost(data=df, 
                       cost_var='TC', 
                       output_var='y', 
                       price_vars=['pl', 'pk', 'pf', 'pm'], 
                       input_vars=['l', 'k', 'f', 'm'], 
                       time_var='year', 
                       id_var='id', 
                       include_time=True, 
                       save_path='Output/test_cost_results.csv'
                      )
# Out:
#      id  year     y      l     k      f           m          pl          pk  \
# 0     1     1  7.87  161.0  2.50  207.5   52.863763   66.234037   3821.7680
# 1     1     2  7.18  138.0  2.50  295.5   56.417048   59.010652   2966.8089
# 2     1     3  8.92  140.0  2.50  362.5  248.361620   71.883786   4925.8810
# 3     1     4  7.31  127.0  2.50  338.0  249.031280   61.053858   4240.7887
# 4     1     5  7.54  145.0  2.50  337.5  225.938370   80.920828   4457.4614
# ..   ..   ...   ...    ...   ...    ...         ...         ...         ...
# 339  43     4  3.31   67.0  2.00   68.0   14.278499   71.508060   1770.2511
# 340  43     5  5.61   96.0  2.00   94.5  168.876290   84.124167   3968.0599
# 341  43     6  7.78   97.0  1.75  129.4   92.618979   57.357938  12207.3420
# 342  43     7  3.70   35.0  1.75  107.1   26.363011  162.443430   3267.6339
# 343  43     8  7.73   81.0  2.00  118.4   28.860614   88.906667   8571.7073
#
# ...

# %% [markdown]
# # Data Envelopment Analysis(DEA)

# %%
exec(open('E:/JupyterWDirectory/MyStock/Functions/Run_Comprehensive_DEA_analysis.py').read())

# %%
# DEA 분석 실행
df = pd.read_csv('data/banking.csv')
results1 = Run_Comprehensive_DEA_analysis(
    data=df,
    input_vars=['employees', 'cost'],
    output_vars=['deposits', 'loans'],
    dmu_var='bank',
    orientation='input',    # 투입물 측면
    models=['CCR', 'BCC'],
    plot_results=True
)
# Out:
# ...
#                      통합 DEA 분석 시스템 (일반화 버전)
# ...
# ?? 데이터 입력 방식: 데이터프레임
#
# ?? 분석 개요
#    ? DMU 수: 20
#    ? 입력 변수 수: 2
#    ? 출력 변수 수: 2
#    ? 분석 방향: INPUT 지향
#    ? 입력 변수: employees, cost
#    ? 출력 변수: deposits, loans
#    ? 분석 모델: CCR, BCC
#
# ?? 데이터 기본 통계:
#    입력 변수 통계:
#      ? employees: 평균 56.70, 표준편차 24.04, 범위 [22.00, 98.00]
#      ? cost: 평균 2258.95, 표준편차 459.12, 범위 [1269.00, 2953.00]
#    출력 변수 통계:
#      ? deposits: 평균 53.80, 표준편차 27.82, 범위 [14.00, 120.00]
#      ? loans: 평균 42.55, 표준편차 19.90, 범위 [13.00, 82.00]
#
# ...
# 1. DEA 모델 효율성 분석
# ...
#
# ?? CCR 모델 분석 중...
#    ? 평균 효율성: 0.7874
#    ? 표준편차: 0.1975
#    ? 효율적 DMU 수: 6
#    ? 최고 효율성: 1.0000
#    ? 최저 효율성: 0.5057
#
# ?? BCC 모델 분석 중...
#    ? 평균 효율성: 0.8437
#    ? 표준편차: 0.1642
#    ? 효율적 DMU 수: 8
#    ? 최고 효율성: 1.0000
#    ? 최저 효율성: 0.5594
#
# ...
# 2. 종합 효율성 분석 결과표
# ...
# DMU  CCR_효율성  CCR_순위  BCC_효율성  BCC_순위  규모효율성 규모수익
#  B1   1.0000       1   1.0000       1 1.0000  CRS
#  B2   1.0000       1   1.0000       1 1.0000  CRS
# ...

# %%
# DEA 분석 실행 (병원 효율성: 산출물 측면)
df = pd.read_csv('data\hospital.csv')
display(df) 
results2 = Run_Comprehensive_DEA_analysis(
    data=df,
    input_vars=['doctors', 'nurses', 'beds'],
    output_vars=['patients', 'surgeries', 'satisfaction'],
    dmu_var='hospital',
    orientation='output',        # 산출물 측면
    models=['BCC'],
    sensitivity_dmu='H5',        # 특정 병원 지정
    change_range=(-0.15, 0.15),  # ±15% 변화
    plot_results=True
)
# Out:
#    hospital  doctors  nurses  beds  patients  surgeries  satisfaction
# 0        H1       12      32   176      1604        168             4
# 1        H2       38     114   268      6198        622             5
# 2        H3       44      69   487      5126        658             4
# 3        H4       48      96   206      5974        685             4
# 4        H5       27     114   425      5426        534             4
# 5        H6       29      77   164      4606        469             4
# 6        H7       32      91   431      4759        506             4
# 7        H8       43      78   414      5527        633             5
# 8        H9       42      37   494      4154        566             5
# 9       H10       19     135   378      5155        351             4
# 10      H11       42     129   305      6272        519             4
# 11      H12       42     122   246      6473        720             4
# ...

# %% [markdown]
# # 정성적 선택 모형

# %%
exec(open('E:/JupyterWDirectory/MyStock/Functions/Run_Qualitative_model_analysis.py').read())

# %%
# 데이터 읽어들이기
mroz = woo.dataWoo('mroz')

# 회귀식 정의 
equation = 'inlf ~ nwifeinc + educ + exper + I(exper**2) + age + kidslt6 + kidsge6'

# 함수 실행
Run_Qualitative_model_analysis(data=mroz, formula=equation)
# Out:
# --- 1. 기초 통계 분석 ---
#
# [기초 통계량 (함수 추정에 사용된 변수만)]
#        nwifeinc       age      educ   kidslt6     exper      inlf   kidsge6
# count  753.0000  753.0000  753.0000  753.0000  753.0000  753.0000  753.0000
# mean    20.1290   42.5378   12.2869    0.2377   10.6308    0.5684    1.3533
# std     11.6348    8.0726    2.2802    0.5240    8.0691    0.4956    1.3199
# min     -0.0291   30.0000    5.0000    0.0000    0.0000    0.0000    0.0000
# 25%     13.0250   36.0000   12.0000    0.0000    4.0000    0.0000    0.0000
# 50%     17.7000   43.0000   12.0000    0.0000    9.0000    1.0000    1.0000
# 75%     24.4660   49.0000   13.0000    0.0000   15.0000    1.0000    2.0000
# max     96.0000   60.0000   17.0000    3.0000   45.0000    1.0000    8.0000
#
# [상관계수 행렬 (함수 추정에 사용된 변수만)]
#           nwifeinc     age    educ  kidslt6   exper    inlf  kidsge6
# nwifeinc    1.0000  0.0586  0.2776   0.0382 -0.1722 -0.1176   0.0248
# age         0.0586  1.0000 -0.1202  -0.4339  0.3340 -0.0805  -0.3854
# ...

# %% [markdown]
# # 패널모형 추정법

# %%
exec(open('E:/JupyterWDirectory/MyStock/Functions/Run_all_Panel_estimations.py').read())

# %%
from linearmodels.datasets import wage_panel

# 데이터 읽어들이기
data = wage_panel.load()
display(data)

# 변수 설정: 컬럼 이름 정의
id_col = "nr"
year_col = "year"
dependent_var = "lwage"

# 독립변수 정의
independent_variables = ["black", "hisp", "exper", "expersq", "married", "educ", "union"]

# 함수 실행
Run_all_Panel_estimations(data, id_col, year_col, dependent_var, independent_variables)
# Out:
#          nr  year  black  exper  hisp  hours  married  educ  union     lwage  \
# 0        13  1980      0      1     0   2672        0    14      0  1.197540
# 1        13  1981      0      2     0   2320        0    14      1  1.853060
# 2        13  1982      0      3     0   2940        0    14      0  1.344462
# 3        13  1983      0      4     0   2960        0    14      0  1.433213
# 4        13  1984      0      5     0   3071        0    14      0  1.568125
# ...     ...   ...    ...    ...   ...    ...      ...   ...    ...       ...
# 4355  12548  1983      0      8     0   2080        1     9      0  1.591879
# 4356  12548  1984      0      9     0   2080        1     9      1  1.212543
# 4357  12548  1985      0     10     0   2080        1     9      0  1.765962
# 4358  12548  1986      0     11     0   2080        1     9      1  1.745894
# 4359  12548  1987      0     12     0   3380        1     9      1  1.466543
#
#       expersq  occupation
# ...

# %% [markdown]
# # SARIMA 자동화

# %%
exec(open('E:/JupyterWDirectory/MyStock/Functions/Run_SARIMAX_analysis.py').read())

# %%
# 한국의 거시경제 통계 자료 불러오기
data = pd.read_csv('Data/Korea_GDP.csv',index_col='Time', parse_dates=True)
new_index = pd.date_range(start='1961-03-31', periods=len(data), freq='Q')
data.index = pd.to_datetime(new_index)
data.index
display(data)

df = data.loc['1969-01-31':]

# SARIMA 자동화
Run_SARIMAX_analysis(data_df=df, variable_name='gdp', freq='Q', seasonal=True, forecast_periods_validation=8, forecast_periods_exante=8)
# Out:
#                  con       inv      gov        ex        im       gdp  \
# 1961-03-31    8957.5    -659.9   3036.1      43.6     292.3    7000.7
# 1961-06-30    6593.8    1736.8   3079.9      56.3     392.2    8141.3
# 1961-09-30    6308.6     833.2   2980.0      70.8     283.1    6970.2
# 1961-12-31    8740.5     950.7   2922.3      66.8     332.0    8974.2
# 1962-03-31    9670.8    -727.9   3058.9      53.9     338.6    7444.8
# ...              ...       ...      ...       ...       ...       ...
# 2022-12-31  235677.7  159480.4  89949.2  222599.2  194751.5  513770.2
# 2023-03-31  233780.3  132942.8  94700.5  212895.0  198370.1  472155.5
# 2023-06-30  229263.8  146189.8  89060.8  217836.1  185450.3  497345.6
# 2023-09-30  233387.8  148498.3  82449.8  229952.8  192882.0  500997.0
# 2023-12-31  237874.7  155198.8  89118.4  244503.0  201819.6  525122.8
#
#                    m2    exch    cpi  rat
# 1961-03-31       24.0     NaN    NaN  NaN
# ...

# %% [markdown]
# # VAR모형의 자동화

# %%
exec(open('E:/JupyterWDirectory/MyStock/Functions/Run_VAR_analysis.py').read())

# %%
# 한국의 거시경제 통계 자료 불러오기
data = pd.read_csv('Data/Korea_GDP.csv',index_col='Time', parse_dates=True)
new_index = pd.date_range(start='1961-03-31', periods=len(data), freq='Q')
data.index = pd.to_datetime(new_index)
data.index
display(data)

df = data.loc['1969-01-31':]

Run_VAR_analysis(
        data=df, 
        endog_vars=['gdp', 'con', 'inv'],
        exog_vars=None,
        diff_type='pct_change',
        pct_change_periods=4,
        start_date='1970-01-31' 
    )
# Out:
#                  con       inv      gov        ex        im       gdp  \
# 1961-03-31    8957.5    -659.9   3036.1      43.6     292.3    7000.7
# 1961-06-30    6593.8    1736.8   3079.9      56.3     392.2    8141.3
# 1961-09-30    6308.6     833.2   2980.0      70.8     283.1    6970.2
# 1961-12-31    8740.5     950.7   2922.3      66.8     332.0    8974.2
# 1962-03-31    9670.8    -727.9   3058.9      53.9     338.6    7444.8
# ...              ...       ...      ...       ...       ...       ...
# 2022-12-31  235677.7  159480.4  89949.2  222599.2  194751.5  513770.2
# 2023-03-31  233780.3  132942.8  94700.5  212895.0  198370.1  472155.5
# 2023-06-30  229263.8  146189.8  89060.8  217836.1  185450.3  497345.6
# 2023-09-30  233387.8  148498.3  82449.8  229952.8  192882.0  500997.0
# 2023-12-31  237874.7  155198.8  89118.4  244503.0  201819.6  525122.8
#
#                    m2    exch    cpi  rat
# 1961-03-31       24.0     NaN    NaN  NaN
# ...
